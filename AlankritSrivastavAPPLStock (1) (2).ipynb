# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import yfinance as yf
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
# For timeseries RNN LSTM neural networks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import MinMaxScaler

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.38)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.25.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2023.4)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.2.2)

# %% [markdown]
# ### Data Set: APPL(Apple Stock: 01/01/2014-06/30/2019)

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# ### Load Dataset

# %%
df_ALL=pd.read_csv('AAPL_stock_data.csv')

# %%
df_ALL.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2014-01-02  19.845715  19.893929  19.715000  19.754642  17.296658
# 1  2014-01-03  19.745001  19.775000  19.301071  19.320715  16.916719
# 2  2014-01-06  19.194643  19.528570  19.057142  19.426071  17.008968
# 3  2014-01-07  19.440001  19.498571  19.211430  19.287144  16.887329
# 4  2014-01-08  19.243214  19.484285  19.238930  19.409286  16.994270
#
#       Volume
# 0  234684800
# 1  392467600
# 2  412610800
# 3  317209200
# 4  258529600

# %% [markdown]
# ### Brief Exploratory Data Analysis (EDA)

# %%
df_ALL.shape
# Out:
# (1382, 7)

# %%
df_ALL.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
# Statistics Sumary
df_ALL.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1382.000000  1382.000000  1382.000000  1382.000000  1382.000000
# mean     33.948871    34.247564    33.653907    33.959740    31.580313
# std       9.725011     9.820676     9.635296     9.729731     9.841611
# min      17.684999    17.911785    17.626785    17.849285    15.628378
# 25%      26.586874    26.826250    26.304375    26.501875    24.170416
# 50%      31.481250    31.712500    31.213750    31.458751    28.320562
# 75%      42.462499    42.804376    42.068750    42.324376    40.078863
# max      57.695000    58.367500    57.445000    58.017502    55.421497
#
#              Volume
# count  1.382000e+03
# mean   1.670774e+08
# std    9.220445e+07
# min    4.590360e+07
# 25%    1.045275e+08
# 50%    1.423682e+08
# 75%    2.034164e+08
# max    1.065523e+09

# %% [markdown]
# ### Keep Only "Close" (for Closing Price) and Filter out all other attributes
# notes: the research focuses only on the closing price

# %%
df = df_ALL.iloc[:,4:5]

# %%
df.head()
# Out:
#        Close
# 0  19.754642
# 1  19.320715
# 2  19.426071
# 3  19.287144
# 4  19.409286

# %%
df.plot(figsize=(12, 8))
# Out:
# <Axes: >

# %% [markdown]
# ### Length of Input Time Series-Number of Input Time Steps

# %%
length60 = 60

# %%
length60
# Out:
# 60

# %% [markdown]
# ### Time Series Dataset: Train / test Split

# %%
len(df)
# Out:
# 1382

# %%
test_precent = 0.1

# %%
len(df)*test_precent
# Out:
# 138.20000000000002

# %% [markdown]
# ### Split Data-->Train / test

# %%
test_length = np.round(len(df)*test_precent)
test_length
# Out:
# 138.0

# %%
split_index = int(len(df) - test_length)
split_index
# Out:
# 1244

# %%
data_train = df.iloc[: split_index]
data_test = df.iloc[split_index - length60 :]

# %%
data_train.head(5)
# Out:
#        Close
# 0  19.754642
# 1  19.320715
# 2  19.426071
# 3  19.287144
# 4  19.409286

# %%
data_train.tail()
# Out:
#           Close
# 1239  46.205002
# 1240  44.172501
# 1241  43.680000
# 1242  42.122501
# 1243  42.400002

# %%
data_test.head(5)
# Out:
#           Close
# 1184  55.959999
# 1185  54.470001
# 1186  54.560001
# 1187  54.592499
# 1188  55.007500

# %%
data_test.tail()
# Out:
#           Close
# 1377  49.645000
# 1378  48.892502
# 1379  49.950001
# 1380  49.935001
# 1381  49.480000

# %% [markdown]
# ### Normalize Data (Scale it into the range[0, 1])

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(data_train)
# Out:
# MinMaxScaler()

# %%
normalized_train = scaler.transform(data_train)
normalized_test = scaler.transform(data_test)

# %% [markdown]
# ### Create TimeseriesGenerator for Training

# %%
batch_size32 = 32
train_tsGenerator60 = TimeseriesGenerator(normalized_train, normalized_train, length=length60, batch_size=batch_size32)

# %%
len(normalized_train)
# Out:
# 1244

# %%
len(train_tsGenerator60)
# Out:
# 37

# %%
x,y = train_tsGenerator60[0]

# %%
# print(x)

# %%
# print(y)

# %% [markdown]
# ### Bulid, Train, and Test Model

# %% [markdown]
# #### Bulid LSTM Model

# %%
n_features = 1

# %%
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
model = Sequential()
model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(length60, n_features)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, activation='relu', return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, activation='relu'))
model.add(Dense(1))

# %% [markdown]
# ### Compile Model

# %%
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  dropout (Dropout)           (None, 60, 50)            0
#
#  lstm_1 (LSTM)               (None, 60, 50)            20200
#
#  dropout_1 (Dropout)         (None, 60, 50)            0
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50851 (198.64 KB)
# Trainable params: 50851 (198.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# 37/37 [==============================] - 8s 205ms/step - loss: 0.0016
# Epoch 75/100
# 37/37 [==============================] - 9s 243ms/step - loss: 0.0015
# Epoch 76/100
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0015
# Epoch 77/100
# 37/37 [==============================] - 8s 210ms/step - loss: 0.0017
# Epoch 78/100
# 37/37 [==============================] - 9s 237ms/step - loss: 0.0014
# Epoch 79/100
# 37/37 [==============================] - 9s 240ms/step - loss: 0.0014
# Epoch 80/100
# 37/37 [==============================] - 8s 212ms/step - loss: 0.0014
# Epoch 81/100
# 37/37 [==============================] - 9s 237ms/step - loss: 0.0017
# Epoch 82/100
# 37/37 [==============================] - 9s 241ms/step - loss: 0.0013
# Epoch 83/100
# 37/37 [==============================] - 8s 222ms/step - loss: 0.0012
# Epoch 84/100
# 37/37 [==============================] - 8s 220ms/step - loss: 0.0023
# Epoch 85/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0012
# Epoch 86/100
# 37/37 [==============================] - 9s 247ms/step - loss: 0.0013
# Epoch 87/100
# 37/37 [==============================] - 9s 249ms/step - loss: 0.0014
# Epoch 88/100
# 37/37 [==============================] - 9s 243ms/step - loss: 0.0033
# Epoch 89/100
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0022
# Epoch 90/100
# 37/37 [==============================] - 9s 249ms/step - loss: 0.0015
# Epoch 91/100
# 37/37 [==============================] - 8s 212ms/step - loss: 0.0020
# Epoch 92/100
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0016
# Epoch 93/100
# 37/37 [==============================] - 9s 247ms/step - loss: 0.0012
# Epoch 94/100
# 37/37 [==============================] - 8s 225ms/step - loss: 0.0013
# Epoch 95/100
# 37/37 [==============================] - 9s 226ms/step - loss: 0.0012
# Epoch 96/100
# 37/37 [==============================] - 9s 244ms/step - loss: 0.0012
# Epoch 97/100
# 37/37 [==============================] - 9s 239ms/step - loss: 0.0015
# Epoch 98/100
# 37/37 [==============================] - 8s 213ms/step - loss: 0.0014
# Epoch 99/100
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0011
# Epoch 100/100
# 37/37 [==============================] - 9s 242ms/step - loss: 0.0011

# %% [markdown]
# ### Visualize Model's Performance after Training

# %%
loss_history_keys = model.history.history.keys()
loss_history_keys
# Out:
# dict_keys(['loss'])

# %%
df_model_loss = pd.DataFrame(model.history.history)
df_model_loss.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Prediciton for Testing: Using TimeseriesGenerator
# #### Create TimeseriesGenerator for Tesing

# %%
batch_size1 = 1
test_tsGenerator60 = TimeseriesGenerator(normalized_test, normalized_test, length=length60, batch_size=batch_size1)

# %% [markdown]
# ### Predicting the  Future Data Points for Testing

# %%
normalized_prediction = model.predict_generator (test_tsGenerator60)

# %%
normalized_prediction
# Out:
# array([[0.6473534 ],
#        [0.6416957 ],
#        [0.63537383],
#        [0.62944865],
#        [0.62317157],
#        [0.616398  ],
#        [0.6098868 ],
#        [0.60292506],
#        [0.59486705],
#        [0.58480525],
#        [0.57251185],
#        [0.560899  ],
#        [0.55085045],
#        [0.5427732 ],
#        [0.5370024 ],
#        [0.53343606],
#        [0.5284229 ],
#        [0.5226044 ],
#        [0.51631653],
#        [0.5105898 ],
#        [0.5063295 ],
#        [0.503779  ],
#        [0.502454  ],
#        [0.50151837],
#        [0.5012533 ],
#        [0.5019462 ],
#        [0.5036439 ],
#        [0.5062825 ],
#        [0.5088004 ],
#        [0.5109294 ],
#        [0.5122956 ],
#        [0.5139327 ],
#        [0.5157198 ],
#        [0.517225  ],
#        [0.520522  ],
#        [0.52599114],
#        [0.53317285],
#        [0.5423341 ],
#        [0.55339736],
#        [0.5655196 ],
#        [0.5769699 ],
#        [0.5867886 ],
#        [0.5943871 ],
#        [0.60009736],
#        [0.6040417 ],
#        [0.6066735 ],
#        [0.6082535 ],
#        [0.60918564],
#        [0.60997033],
#        [0.6105614 ],
#        [0.611434  ],
#        [0.612916  ],
#        [0.61495197],
#        [0.61746335],
#        [0.6198262 ],
#        [0.62222326],
#        [0.62477773],
#        [0.6273205 ],
#        [0.6294816 ],
#        [0.6306908 ],
#        [0.6310464 ],
#        [0.6321161 ],
#        [0.63459957],
#        [0.6385312 ],
#        [0.6439464 ],
#        [0.6508659 ],
#        [0.6591149 ],
#        [0.66761094],
#        [0.676034  ],
#        [0.68561864],
#        [0.694967  ],
#        [0.70283663],
#        [0.70835847],
#        [0.7119882 ],
#        [0.7141607 ],
#        [0.71558034],
#        [0.71690434],
#        [0.7190106 ],
#        [0.722225  ],
#        [0.7263639 ],
#        [0.7313324 ],
#        [0.73747516],
#        [0.7441599 ],
#        [0.7510997 ],
#        [0.75738883],
#        [0.7626379 ],
#        [0.7668131 ],
#        [0.7699642 ],
#        [0.77321947],
#        [0.7768884 ],
#        [0.78102756],
#        [0.78615755],
#        [0.7918594 ],
#        [0.7971599 ],
#        [0.80139434],
#        [0.8044953 ],
#        [0.8054924 ],
#        [0.8072448 ],
#        [0.8097566 ],
#        [0.81358624],
#        [0.8175026 ],
#        [0.81951475],
#        [0.81947696],
#        [0.81716716],
#        [0.81225663],
#        [0.80263853],
#        [0.79027605],
#        [0.7772462 ],
#        [0.76466066],
#        [0.75309217],
#        [0.7416149 ],
#        [0.7313448 ],
#        [0.7217691 ],
#        [0.7123331 ],
#        [0.70308983],
#        [0.6941983 ],
#        [0.6857939 ],
#        [0.6783601 ],
#        [0.67137754],
#        [0.6645138 ],
#        [0.65933526],
#        [0.6567827 ],
#        [0.6573006 ],
#        [0.6615118 ],
#        [0.66916966],
#        [0.6796547 ],
#        [0.69149566],
#        [0.70338786],
#        [0.7139908 ],
#        [0.7230034 ],
#        [0.7314146 ],
#        [0.73906624],
#        [0.7462142 ],
#        [0.7525357 ],
#        [0.7578292 ],
#        [0.7612685 ],
#        [0.7640255 ],
#        [0.76637936]], dtype=float32)

# %%
len(normalized_prediction)
# Out:
# 138

# %%
# convert normalized predictions back to the true values
prediction = scaler.inverse_transform(normalized_prediction)

# %%
prediction_index = np.arange(1244, 1382, step=1)

df_prediction = pd.DataFrame(data=prediction, index=prediction_index, columns=['Prediction'])

# %%
df_prediction
# Out:
#       Prediction
# 1244   43.852314
# 1245   43.625057
# 1246   43.371117
# 1247   43.133114
# 1248   42.880974
# ...          ...
# 1377   48.077301
# 1378   48.289932
# 1379   48.428082
# 1380   48.538830
# 1381   48.633377
#
# [138 rows x 1 columns]

# %% [markdown]
# ### Visualize Prediction

# %%
ax = data_train.plot()
df_prediction.plot(ax=ax, figsize=(8, 12))
# Out:
# <Axes: >

# %% [markdown]
# ### Visualize Prediction and compare actual close price

# %%
ax = df.plot()
df_prediction.plot(ax=ax, figsize=(8, 12))
# Out:
# <Axes: >

# %% [markdown]
# # Time Series Forecasting with LSTM

# %% [markdown]
# # PreProcess Full Input Dataset

# %%
#Still use Minmax Scaler to normalize the full input dataset

full_scaler = MinMaxScaler()
normalized_full_data = full_scaler.fit_transform(df)

# %% [markdown]
# # Create TimeSeriesGenerator for Forecasting

# %%
# Number of time steps of the input time series

length60
# Out:
# 60

# %%
# create timeseries Generator for forecasting
forecast_tsGenerator = TimeseriesGenerator(normalized_full_data, normalized_full_data, length=length60, batch_size=batch_size32)

# %% [markdown]
# # Build, Compile, and Fit LSTM model for Forecasting

# %%
# Train/Fit LSTM model
# In forecasting, we don't valiate, only FORECAST
# So, not need EarlyStop: Not need validation_generator

model.fit_generator(forecast_tsGenerator, epochs = 100)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0012
# Epoch 2/100
# 42/42 [==============================] - 10s 237ms/step - loss: 0.0017
# Epoch 3/100
# 42/42 [==============================] - 10s 242ms/step - loss: 0.0015
# Epoch 4/100
# 42/42 [==============================] - 9s 210ms/step - loss: 0.0012
# Epoch 5/100
# 42/42 [==============================] - 10s 237ms/step - loss: 0.0013
# Epoch 6/100
# 42/42 [==============================] - 10s 243ms/step - loss: 0.0013
# Epoch 7/100
# 42/42 [==============================] - 10s 243ms/step - loss: 0.0013
# Epoch 8/100
# 42/42 [==============================] - 10s 242ms/step - loss: 0.0011
# Epoch 9/100
# 42/42 [==============================] - 9s 217ms/step - loss: 0.0012
# Epoch 10/100
# 42/42 [==============================] - 12s 276ms/step - loss: 0.0012
# Epoch 11/100
# 42/42 [==============================] - 10s 240ms/step - loss: 0.0012
# Epoch 12/100
# 42/42 [==============================] - 10s 243ms/step - loss: 0.0014
# Epoch 13/100
# 42/42 [==============================] - 10s 250ms/step - loss: 0.0018
# Epoch 14/100
# 42/42 [==============================] - 9s 212ms/step - loss: 0.0015
# Epoch 15/100
# 42/42 [==============================] - 10s 242ms/step - loss: 0.0016
# Epoch 16/100
# 42/42 [==============================] - 10s 242ms/step - loss: 0.0015
# Epoch 88/100
# 42/42 [==============================] - 10s 241ms/step - loss: 0.0011
# Epoch 89/100
# 42/42 [==============================] - 10s 245ms/step - loss: 8.4378e-04
# Epoch 90/100
# 42/42 [==============================] - 10s 248ms/step - loss: 7.6915e-04
# Epoch 91/100
# 42/42 [==============================] - 9s 219ms/step - loss: 7.5121e-04
# Epoch 92/100
# 42/42 [==============================] - 10s 250ms/step - loss: 9.6014e-04
# Epoch 93/100
# 42/42 [==============================] - 10s 247ms/step - loss: 9.7575e-04
# Epoch 94/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0011
# Epoch 95/100
# 42/42 [==============================] - 10s 249ms/step - loss: 9.9525e-04
# Epoch 96/100
# 42/42 [==============================] - 10s 228ms/step - loss: 0.0010
# Epoch 97/100
# 42/42 [==============================] - 11s 254ms/step - loss: 8.9706e-04
# Epoch 98/100
# 42/42 [==============================] - 10s 249ms/step - loss: 8.5132e-04
# Epoch 99/100
# 42/42 [==============================] - 10s 248ms/step - loss: 9.4231e-04
# Epoch 100/100
# 42/42 [==============================] - 10s 244ms/step - loss: 7.5773e-04

# %% [markdown]
# # Time Series Forecasting Using LSTM Neural Network: 07/01/2019 - 12/15/2019

# %%
forecast = []
# Set periods with the time span of forecasting
# Let's forecast for the next 107 business days (07/01/2019 - 12/15/2019)
periods = 117

first_eval_batch = normalized_full_data[-length60:]
current_batch = first_eval_batch.reshape((1, length60, n_features))

for i in range(periods):

    # get prediction 1 time stamp ahead([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]

    # store prediction
    forecast.append(current_pred)

    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:], [[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 77ms/step

# %% [markdown]
# # Inverse to Transform Normalized Data Back into True Values

# %%
forecast = full_scaler.inverse_transform(forecast)

forecast
# Out:
# array([[49.35263687],
#        [49.29977266],
#        [49.21357144],
#        [49.11734087],
#        [49.02304482],
#        [48.93690824],
#        [48.86137085],
#        [48.79691386],
#        [48.74301296],
#        [48.69862187],
#        [48.66243335],
#        [48.63303242],
#        [48.60902805],
#        [48.58911778],
#        [48.57213564],
#        [48.55709759],
#        [48.54320637],
#        [48.52983709],
#        [48.51655639],
#        [48.50306979],
#        [48.48921209],
#        [48.47492104],
#        [48.46021818],
#        [48.44516338],
#        [48.42987394],
#        [48.41445521],
#        [48.39904606],
#        [48.38375662],
#        [48.36869223],
#        [48.35394868],
#        [48.33959298],
#        [48.32567303],
#        [48.31222713],
#        [48.29927205],
#        [48.28681017],
#        [48.27483911],
#        [48.26333492],
#        [48.25229042],
#        [48.2416697 ],
#        [48.2314512 ],
#        [48.22161338],
#        [48.21212751],
#        [48.20296965],
#        [48.19412303],
#        [48.18556373],
#        [48.17728454],
#        [48.16925435],
#        [48.16147795],
#        [48.15393858],
#        [48.14662426],
#        [48.13953021],
#        [48.13264924],
#        [48.12597657],
#        [48.11950262],
#        [48.11322978],
#        [48.1071437 ],
#        [48.10124915],
#        [48.09552937],
#        [48.08999156],
#        [48.08462374],
#        [48.07942351],
#        [48.07438129],
#        [48.0694995 ],
#        [48.06476853],
#        [48.0601884 ],
#        [48.05574475],
#        [48.05144474],
#        [48.04727642],
#        [48.04323738],
#        [48.03932524],
#        [48.03553281],
#        [48.0318553 ],
#        [48.02829271],
#        [48.02484265],
#        [48.02149793],
#        [48.01825138],
#        [48.01511018],
#        [48.01206474],
#        [48.00911267],
#        [48.00625159],
#        [48.0034767 ],
#        [48.000788  ],
#        [47.99818309],
#        [47.99565481],
#        [47.99320792],
#        [47.99083286],
#        [47.98852963],
#        [47.98630062],
#        [47.98413865],
#        [47.98204132],
#        [47.98000863],
#        [47.97803819],
#        [47.97612761],
#        [47.97427928],
#        [47.97248362],
#        [47.97074542],
#        [47.96905511],
#        [47.96742226],
#        [47.96583729],
#        [47.9643002 ],
#        [47.962811  ],
#        [47.9613649 ],
#        [47.95996668],
#        [47.95860677],
#        [47.95729234],
#        [47.95601623],
#        [47.95477842],
#        [47.95357892],
#        [47.95241533],
#        [47.95129005],
#        [47.95019829],
#        [47.94913766],
#        [47.94810814],
#        [47.94711455],
#        [47.94614728],
#        [47.94521354],
#        [47.94430614]])

# %%
df
# Out:
#           Close
# 0     19.754642
# 1     19.320715
# 2     19.426071
# 3     19.287144
# 4     19.409286
# ...         ...
# 1377  49.645000
# 1378  48.892502
# 1379  49.950001
# 1380  49.935001
# 1381  49.480000
#
# [1382 rows x 1 columns]

# %% [markdown]
# # Creating new time stamp index with pandas : 07/01/2019 - 12/15/2019

# %%
#calculate forecast index

forecast_index = np.arange(1382,1499,step=1)

# %%
# Assuming forecast is your array of values and forecast_index is your array of indices
# Ensure that forecast_index is properly defined and not empty
if len(forecast_index) == 0:
    raise ValueError("forecast_index is empty.")

# Create the DataFrame
forecast_df = pd.DataFrame(data=forecast, index=forecast_index, columns=['Forecast'])

# %%
forecast_df=pd.DataFrame(data=forecast,index=forecast_index,columns=['Forecast'])

# %%
forecast_df
# Out:
#        Forecast
# 1382  49.352637
# 1383  49.299773
# 1384  49.213571
# 1385  49.117341
# 1386  49.023045
# ...         ...
# 1494  47.948108
# 1495  47.947115
# 1496  47.946147
# 1497  47.945214
# 1498  47.944306
#
# [117 rows x 1 columns]

# %%
df.plot()
forecast_df.plot()
# Out:
# <Axes: >

# %%
ax=df.plot()
forecast_df.plot(ax=ax, figsize=(12,8))
# Out:
# <Axes: >

# %%
df_ALL_JUL_DEC_2019 = pd.read_csv('AAPL_stock_data.csv')

# %%
df_ALL_JUL_DEC_2019.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2014-01-02  19.845715  19.893929  19.715000  19.754642  17.296658
# 1  2014-01-03  19.745001  19.775000  19.301071  19.320715  16.916719
# 2  2014-01-06  19.194643  19.528570  19.057142  19.426071  17.008968
# 3  2014-01-07  19.440001  19.498571  19.211430  19.287144  16.887329
# 4  2014-01-08  19.243214  19.484285  19.238930  19.409286  16.994270
#
#       Volume
# 0  234684800
# 1  392467600
# 2  412610800
# 3  317209200
# 4  258529600

# %%
df_JUL_DEC_2019=df_ALL_JUL_DEC_2019.iloc[:,4:5]

# %%
df_JUL_DEC_2019
# Out:
#           Close
# 0     19.754642
# 1     19.320715
# 2     19.426071
# 3     19.287144
# 4     19.409286
# ...         ...
# 1377  49.645000
# 1378  48.892502
# 1379  49.950001
# 1380  49.935001
# 1381  49.480000
#
# [1382 rows x 1 columns]

# %%
df_JUL_DEC_2019.plot()
# Out:
# <Axes: >

# %%
forecast_df['Forecast'].values
# Out:
# array([49.35263687, 49.29977266, 49.21357144, 49.11734087, 49.02304482,
#        48.93690824, 48.86137085, 48.79691386, 48.74301296, 48.69862187,
#        48.66243335, 48.63303242, 48.60902805, 48.58911778, 48.57213564,
#        48.55709759, 48.54320637, 48.52983709, 48.51655639, 48.50306979,
#        48.48921209, 48.47492104, 48.46021818, 48.44516338, 48.42987394,
#        48.41445521, 48.39904606, 48.38375662, 48.36869223, 48.35394868,
#        48.33959298, 48.32567303, 48.31222713, 48.29927205, 48.28681017,
#        48.27483911, 48.26333492, 48.25229042, 48.2416697 , 48.2314512 ,
#        48.22161338, 48.21212751, 48.20296965, 48.19412303, 48.18556373,
#        48.17728454, 48.16925435, 48.16147795, 48.15393858, 48.14662426,
#        48.13953021, 48.13264924, 48.12597657, 48.11950262, 48.11322978,
#        48.1071437 , 48.10124915, 48.09552937, 48.08999156, 48.08462374,
#        48.07942351, 48.07438129, 48.0694995 , 48.06476853, 48.0601884 ,
#        48.05574475, 48.05144474, 48.04727642, 48.04323738, 48.03932524,
#        48.03553281, 48.0318553 , 48.02829271, 48.02484265, 48.02149793,
#        48.01825138, 48.01511018, 48.01206474, 48.00911267, 48.00625159,
#        48.0034767 , 48.000788  , 47.99818309, 47.99565481, 47.99320792,
#        47.99083286, 47.98852963, 47.98630062, 47.98413865, 47.98204132,
#        47.98000863, 47.97803819, 47.97612761, 47.97427928, 47.97248362,
#        47.97074542, 47.96905511, 47.96742226, 47.96583729, 47.9643002 ,
#        47.962811  , 47.9613649 , 47.95996668, 47.95860677, 47.95729234,
#        47.95601623, 47.95477842, 47.95357892, 47.95241533, 47.95129005,
#        47.95019829, 47.94913766, 47.94810814, 47.94711455, 47.94614728,
#        47.94521354, 47.94430614])

# %%
df_JUL_DEC_2019
# Out:
#           Close
# 0     19.754642
# 1     19.320715
# 2     19.426071
# 3     19.287144
# 4     19.409286
# ...         ...
# 1377  49.645000
# 1378  48.892502
# 1379  49.950001
# 1380  49.935001
# 1381  49.480000
#
# [1382 rows x 1 columns]

# %%
df_JUL_DEC_2019.plot()
# Out:
# <Axes: >
